# %% [markdown]
# <a href="https://colab.research.google.com/github/PiyushAgarwal14/DIP/blob/main/DIP_04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cv2 as cv

from google.colab.patches import cv2_imshow
from skimage import io
from PIL import Image

# %%
img= cv.imread("/content/house.jpg")
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=275x183 at 0x7F37167C2110>

# %%
img= cv.imread("/content/house.jpg")
plt.grid('img')
plt.xlabel('X-AXIS')
plt.ylabel('Y-AXIS')
plt.imshow(img)

# %%
img1 = plt.imread('/content/SUNSET.jpg')
print("Original Shape", img.shape)
cv2_imshow(img1)
scale_per = 50
width = int(img1.shape[1]*scale_per / 100)
height = int(img1.shape[0]*scale_per / 100)
img_res = cv.resize(img1,(width,height))
print("\n \n Resized Shape", img_res.shape)
cv2_imshow(img_res)
# Out:
# Original Shape (183, 275, 3)
# <PIL.Image.Image image mode=RGB size=495x348 at 0x7F3758D205E0>
#
#  Resized Shape (174, 247, 3)
# <PIL.Image.Image image mode=RGB size=247x174 at 0x7F3758D20FD0>

# %%
print("Resize Image Horizontally \n")
scale_per = 75
width= int(img1.shape[1]*scale_per / 100)
img_resh = cv.resize(img1,(width,img1.shape[0]))

print("Original Shape", img.shape)
cv2_imshow(img1)

print("\n Resize Shape", img.shape)
cv2_imshow(img_resh)
# Out:
# Resize Image Horizontally
#
# Original Shape (183, 275, 3)
# <PIL.Image.Image image mode=RGB size=495x348 at 0x7F3758D353C0>
#  Resize Shape (183, 275, 3)
# <PIL.Image.Image image mode=RGB size=371x348 at 0x7F3758D347C0>

# %%
my_img = cv.imread("/content/house.jpg")
print(my_img.shape)

img2 = my_img + 50
cv2_imshow(img2)

print("\n")
img3 = my_img -5
cv2_imshow(img3)

print("\n")
img4 = my_img *5
cv2_imshow(img4)

print("\n")
img5 = my_img /5
cv2_imshow(img5)
# Out:
# (183, 275, 3)
# <PIL.Image.Image image mode=RGB size=275x183 at 0x7F3713AB8AF0>
# <PIL.Image.Image image mode=RGB size=275x183 at 0x7F3713AB8AF0>
# <PIL.Image.Image image mode=RGB size=275x183 at 0x7F3713AB82B0>
# <PIL.Image.Image image mode=RGB size=275x183 at 0x7F3713AB82B0>
