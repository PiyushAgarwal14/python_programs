# %% [markdown]
# <a href="https://colab.research.google.com/github/PiyushAgarwal14/python_programs/blob/main/DIP9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import cv2
from google.colab.patches import cv2_imshow

# %%
img = cv2.imread('/content/Wiki.png',0)
equ = cv2.equalizeHist(img)
res = np.hstack((img,equ))
cv2.imwrite('/content/Car.jpg',res)
# Out:
# True

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=L size=512x512 at 0x7F2270BEEDD0>

# %%
cv2_imshow(res)
# Out:
# <PIL.Image.Image image mode=L size=1024x512 at 0x7F222F69BE50>
